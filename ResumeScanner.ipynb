# %% [markdown]
# <a href="https://colab.research.google.com/github/jeev64/Python/blob/master/ResumeScanner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install docx2txt
# Out:
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-cp36-none-any.whl size=3965 sha256=12df1d718020809f6b9f9565a7d4640db240d7e98107e326aaf7663197f8b6cf
#   Stored in directory: /root/.cache/pip/wheels/b2/1f/26/a051209bbb77fc6bcfae2bb7e01fa0ff941b82292ab084d596
# Successfully built docx2txt
# ...

# %%
import docx2txt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8706b4d0-dc69-473e-a94e-da0be15f2372" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8706b4d0-dc69-473e-a94e-da0be15f2372">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Head of Change Management and Competency Modelling.docx to Head of Change Management and Competency Modelling.docx
# Saving Resume HR Latest Test.docx to Resume HR Latest Test (1).docx

# %%
resume = docx2txt.process("Resume HR Latest Test.docx") 

print(resume)
# Out:
# Curriculum Vitae
#
#
#
#
#
# Profile: Over the past 20 years, I have gained strong through knowledge of Talent Management, HR Business Partner, and as a regional contributor for several MNCs.
#
#
#
# I am a professionally qualified Talent Management Senior Manager with more than 20 years’ experience in recruitment, compensation & benefits, succession planning, performance management, leadership development, and HR Analytics.
#
#
#
# I am accomplished in all areas of talent management: in particular, having proven success in talent management functions transcending Malaysia, Singapore, Hong Kong, Korea, New Zealand, and Australia. I thrive on new challenges, and my innovative approach to HR systems and improvement, along with my desire to learn, will prove to be an asset to my employer.
#
#
#
# When you review my enclosed resume, you will find that my background also includes a master's degree in business administration (MBA).
#
#
#
#
#
#
#
# CAREER OBJECTIVE
#
# ...

# %%
jobDescription = docx2txt.process("Head of Change Management and Competency Modelling.docx")
print(jobDescription)
# Out:
# Manager of HR Transformation Job Description
#
# Reporting to the Head of I.T. the Manager of HR Transformation will be instrumental in delivering a complete capability assessment of an I.T. Department of 500+, making recommendations on skills training and development programs and assisting a team in delivering these recommendations.
#
# Key aspects of this role will also include the following;
#
# Capturing the as-is processes, re-design ‘to-be’ processes and translating these into user requirements.
#
# Make recommendations and identify opportunities for training, additional certification requirements, behavioural and development programs.
#
# Identify opportunities for business process re-engineering and system improvements and enhancements.
#
# Conduct Senior Management competency improvement workshops and ongoing training as required.
#
# Review the HR Scorecard for the Human Resource Information System and translate into business requirements.
#
# ...

# %%
text = [resume, jobDescription]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
countMatrix = cv.fit_transform(text)

# %%
from sklearn.metrics.pairwise import cosine_similarity
print("\n similarity score: ")
print(cosine_similarity(countMatrix))
# Out:
#  similarity score:
# [[1.        0.7661405]
#  [0.7661405 1.       ]]

# %%
matchPercentage = cosine_similarity (countMatrix) [0][1] * 100
matchPercentage = round(matchPercentage, 2)
print(matchPercentage)
# Out:
# 76.61
